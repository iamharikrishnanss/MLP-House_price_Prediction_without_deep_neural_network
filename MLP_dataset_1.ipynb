# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/House_pre/kc_house_data.csv")
data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15     price
# 0    98178  47.5112 -122.257           1340        5650  221900.0
# 1    98125  47.7210 -122.319           1690        7639  538000.0
# 2    98028  47.7379 -122.233           2720        8062  180000.0
# 3    98136  47.5208 -122.393           1360        5000  604000.0
# 4    98074  47.6168 -122.045           1800        7503  510000.0

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
import statsmodels.api as sm

# %%
x_train_sm = sm.add_constant(X_train)
x_train_sm
# Out:
#        const  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 21350    1.0         3       2.25         2890      5000     3.0           0
# 10869    1.0         5       2.50         2500     12220     1.0           0
# 17014    1.0         3       2.25         1710     21485     2.0           0
# 4370     1.0         4       2.50         3000      8645     2.0           0
# 4058     1.0         3       1.00         1030      9916     1.0           0
# ...      ...       ...        ...          ...       ...     ...         ...
# 15848    1.0         5       3.50         5930     13288     2.0           0
# 778      1.0         4       2.50         2710      5880     2.0           0
# 16       1.0         3       2.00         1890     14040     2.0           0
# 20957    1.0         4       2.50         2580      4818     2.0           0
# 21075    1.0         3       2.50         1780      1487     3.0           0
#
#        view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 21350     0          3      9        2890              0      2014
# 10869     0          3      8        1690            810      1962
# 17014     0          3      7        1710              0      1989
# 4370      0          3      8        3000              0      1985
# 4058      0          4      7        1030              0      1972
# ...     ...        ...    ...         ...            ...       ...
# 15848     2          3     11        3920           2010      1996
# 778       0          3      9        2710              0      1998
# 16        0          3      7        1890              0      1994
# 20957     0          3      8        2580              0      2005
# 21075     0          3      8        1600            180      2006
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 21350             0    98117  47.6983 -122.389           2020        5000
# 10869             0    98003  47.3335 -122.325           2130       12000
# 17014             0    98074  47.6198 -122.053           1680       21485
# 4370              0    98034  47.7315 -122.224           1930        8866
# 4058              0    98034  47.7218 -122.176           1470        9044
# ...             ...      ...      ...      ...            ...         ...
# 15848             0    98027  47.5542 -122.097           3860       12062
# 778               0    98092  47.3314 -122.172           2520        6000
# 16                0    98019  47.7277 -121.962           1890       14018
# 20957             0    98038  47.3607 -122.038           2570        5386
# 21075             0    98107  47.6539 -122.351           1780        1300
#
# [15129 rows x 19 columns]

# %%
lr = sm.OLS(y_train,x_train_sm).fit()
lr

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     2099.
# Date:                Tue, 09 May 2023   Prob (F-statistic):               0.00
# Time:                        06:03:44   Log-Likelihood:            -2.0627e+05
# No. Observations:               15129   AIC:                         4.126e+05
# Df Residuals:                   15111   BIC:                         4.127e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          8.532e+06   3.53e+06      2.416      0.016    1.61e+06    1.55e+07
# bedrooms       -4.17e+04   2355.305    -17.703      0.000   -4.63e+04   -3.71e+04
# bathrooms      4.323e+04   3898.019     11.090      0.000    3.56e+04    5.09e+04
# sqft_living     114.9812      2.753     41.765      0.000     109.585     120.377
# sqft_lot          0.1679      0.056      2.984      0.003       0.058       0.278
# floors         6462.1267   4374.087      1.477      0.140   -2111.614     1.5e+04
# waterfront     5.987e+05   2.08e+04     28.724      0.000    5.58e+05     6.4e+05
# view           5.646e+04   2574.610     21.928      0.000    5.14e+04    6.15e+04
# condition      2.737e+04   2830.073      9.671      0.000    2.18e+04    3.29e+04
# grade          9.332e+04   2598.973     35.905      0.000    8.82e+04    9.84e+04
# sqft_above       76.0027      2.721     27.934      0.000      70.670      81.336
# sqft_basement    38.9859      3.179     12.262      0.000      32.754      45.218
# yr_built      -2702.0412     87.997    -30.706      0.000   -2874.525   -2529.557
# yr_renovated     16.6518      4.455      3.738      0.000       7.919      25.384
# zipcode        -615.1616     39.801    -15.456      0.000    -693.175    -537.148
# lat             6.05e+05   1.29e+04     46.966      0.000     5.8e+05     6.3e+05
# long          -2.265e+05   1.56e+04    -14.519      0.000   -2.57e+05   -1.96e+05
# sqft_living15    20.2568      4.136      4.898      0.000      12.150      28.364
# sqft_lot15       -0.4296      0.087     -4.930      0.000      -0.600      -0.259
# ==============================================================================
# Omnibus:                    13455.489   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1624158.259
# Skew:                           3.780   Prob(JB):                         0.00
# Kurtosis:                      53.193   Cond. No.                     2.40e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.66e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
data = data.drop('floors',axis = 1)
# data = data.drop('zipcode',axis = 1)
data.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'waterfront',
#        'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
data = data.dropna(how ='any')

# %% [markdown]
# **MLP**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

scaler = MinMaxScaler()
X_rescaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_rescaled, y, test_size=0.3)

# %%
from sklearn.neural_network import MLPRegressor
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

# %%
house_mlp = MLPRegressor(hidden_layer_sizes=(10,),max_iter=200)
house_mlp.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=(10,))

# %%
y_pred = house_mlp.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
mse = mean_squared_error(y_test, y_pred)
print("MSE:",mse)
print("RMSE:",np.sqrt(mse))
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("MAPE:", mape)
# Out:
# MSE: 421114215817.7955
# RMSE: 648933.1366310365
# MAE: 532158.2639415964
# MAPE: 97.82722380943385

# %% [markdown]
# # **Tune MLP**
# tuning is necessary.
#
# The following are different parameters that can be tuned:
#
# - hidden_layer_sizes
# - alpha, default=0.0001
# - learning_rate{‘constant’, ‘invscaling’, ‘adaptive’}, default=’constant’
# - learning_rate_init, default=0.001
# - max_iter, default=200
# - shuffle, default=True
#
# To tune MLP, we cannot use the testset. Why?
#
# So we chunk out another part of trainset as a tuning (validation) set. We use this set only tune the algorithm.

# %%
# Create tuning (validation) set: devide the trainset

X_train_s, X_tune, y_train_s, y_tune = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)

print('X_train_s Shape: ', X_train_s.shape)
print('X_tune Shape: ', X_tune.shape)
print('y_train_s Shape: ', y_train_s.shape)
print('y_tune Shape: ', y_tune.shape)
# Out:
# X_train Shape:  (15129, 18)
# y_train Shape:  (15129,)
# X_train_s Shape:  (12103, 18)
# X_tune Shape:  (3026, 18)
# y_train_s Shape:  (12103,)
# y_tune Shape:  (3026,)

# %% [markdown]
# #Tune for hidden_layer_Node

# %%
PossibleNetStrct = []
PossibleNetString = []

for i in range(1, 16):
    netStruct = [i]
    PossibleNetStrct.append(netStruct)
    PossibleNetString.append(str(netStruct))
    # print('Network Structure:', netStruct)

# %%
num_repetition = 5

# %%
tune_df = pd.DataFrame(np.nan, index =PossibleNetString,
                      columns = ['R{}'.format(i) for i in range(num_repetition)])

n = len(y_tune)

for i,netStr in enumerate(PossibleNetStrct):
    RowName = PossibleNetString[i]
    for rep in tune_df.columns:
        
        house_mlp = MLPRegressor(hidden_layer_sizes=netStr, activation = 'relu', 
                       solver='lbfgs', max_iter=2000)
        house_mlp.fit(X_train_s, y_train_s)
        
        y_tune_predict = house_mlp.predict(X_tune)
        RSME = np.sqrt(np.sum((y_tune_predict - y_tune)**2)/n)
        
        tune_df.at[RowName, rep] = RSME
    print(netStr)
# Out:
# [1]
# [2]
# [3]
# [4]
# [5]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [6]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [7]
# [8]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [9]
# [10]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [11]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [12]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [13]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [14]
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [15]

# %%
tune_df['Mean'] = tune_df[
    ['R{}'.format(i) for i in range(num_repetition)]].mean(axis=1)
tune_df['Min'] = tune_df[
    ['R{}'.format(i) for i in range(num_repetition)]].min(axis=1)
tune_df.sort_values('Min')
# Out:
#                  R0             R1             R2             R3  \
# [13]  136248.549276  171612.707426  142451.703900  162115.166011
# [15]  169362.727812  140876.963450  160323.525801  162382.241654
# [9]   165811.816867  140922.644191  165041.812732  163518.596823
# [14]  168119.883069  169992.696187  147906.519920  143598.158319
# [11]  146001.945503  164244.993542  166099.889733  165636.829009
# [12]  175616.319001  168449.779513  161942.957859  149180.190496
# [6]   162869.442703  166130.423301  166263.447662  161890.587940
# [5]   170704.284849  168520.444143  164534.882321  168804.339673
# [8]   195071.014479  165489.624261  194571.904544  167128.882612
# [10]  166100.845858  166118.185451  165654.217881  166046.519663
# [7]   171754.579586  168543.523359  168529.045873  171900.847165
# [3]   168877.740100  200379.463817  168624.164403  194595.329068
# [4]   188148.643505  194583.882935  188153.720993  188172.391300
# [2]   188169.648211  194582.804417  188172.941196  355485.677556
# [1]   188172.073997  355485.676159  355485.676159  355485.676156
#
#                  R4           Mean            Min
# [13]  169335.398320  156352.704987  136248.549276
# [15]  162892.574788  159167.606701  140876.963450
# [9]   165839.839856  160226.942094  140922.644191
# [14]  182593.202348  162442.091969  143598.158319
# [11]  166193.407196  161635.412997  146001.945503
# [12]  164643.212175  163966.491809  149180.190496
# [6]   162588.432912  163948.466904  161890.587940
# [5]   165983.824464  167709.555090  164534.882321
# [8]   168556.331191  178163.551417  165489.624261
# [10]  168578.191558  166499.592082  165654.217881
# [7]   194584.045483  175062.408293  168529.045873
# [3]   355485.676272  217592.474732  168624.164403
# [4]   194584.461763  190728.620099  188148.643505
# [2]   355485.676972  256379.349670  188169.648211
# [1]   355485.676159  322022.955726  188172.073997

# %%
tune_df.sort_values('Mean')
# Out:
#                  R0             R1             R2             R3  \
# [13]  136248.549276  171612.707426  142451.703900  162115.166011
# [15]  169362.727812  140876.963450  160323.525801  162382.241654
# [9]   165811.816867  140922.644191  165041.812732  163518.596823
# [11]  146001.945503  164244.993542  166099.889733  165636.829009
# [14]  168119.883069  169992.696187  147906.519920  143598.158319
# [6]   162869.442703  166130.423301  166263.447662  161890.587940
# [12]  175616.319001  168449.779513  161942.957859  149180.190496
# [10]  166100.845858  166118.185451  165654.217881  166046.519663
# [5]   170704.284849  168520.444143  164534.882321  168804.339673
# [7]   171754.579586  168543.523359  168529.045873  171900.847165
# [8]   195071.014479  165489.624261  194571.904544  167128.882612
# [4]   188148.643505  194583.882935  188153.720993  188172.391300
# [3]   168877.740100  200379.463817  168624.164403  194595.329068
# [2]   188169.648211  194582.804417  188172.941196  355485.677556
# [1]   188172.073997  355485.676159  355485.676159  355485.676156
#
#                  R4           Mean            Min
# [13]  169335.398320  156352.704987  136248.549276
# [15]  162892.574788  159167.606701  140876.963450
# [9]   165839.839856  160226.942094  140922.644191
# [11]  166193.407196  161635.412997  146001.945503
# [14]  182593.202348  162442.091969  143598.158319
# [6]   162588.432912  163948.466904  161890.587940
# [12]  164643.212175  163966.491809  149180.190496
# [10]  168578.191558  166499.592082  165654.217881
# [5]   165983.824464  167709.555090  164534.882321
# [7]   194584.045483  175062.408293  168529.045873
# [8]   168556.331191  178163.551417  165489.624261
# [4]   194584.461763  190728.620099  188148.643505
# [3]   355485.676272  217592.474732  168624.164403
# [2]   355485.676972  256379.349670  188169.648211
# [1]   355485.676159  322022.955726  188172.073997

# %% [markdown]
# # Tune for learning_rate, learning_rate_init

# %%
# LR_options = ['constant','invscaling','adaptive']
# LRI_options = [0.0001,0.001,0.005,0.01,0.05,0.1]

# my_index = pd.MultiIndex.from_product([LR_options,LRI_options],
#                                      names=('LR', 'rate'))

# tune_df = pd.DataFrame(index = my_index,
#                        columns=['R{}'.format(i) for i in range(num_repetition)])

# tune_df
# Out:
#                     R0   R1   R2   R3   R4
# LR         rate
# constant   0.0001  NaN  NaN  NaN  NaN  NaN
#            0.0010  NaN  NaN  NaN  NaN  NaN
#            0.0050  NaN  NaN  NaN  NaN  NaN
#            0.0100  NaN  NaN  NaN  NaN  NaN
#            0.0500  NaN  NaN  NaN  NaN  NaN
#            0.1000  NaN  NaN  NaN  NaN  NaN
# invscaling 0.0001  NaN  NaN  NaN  NaN  NaN
#            0.0010  NaN  NaN  NaN  NaN  NaN
#            0.0050  NaN  NaN  NaN  NaN  NaN
#            0.0100  NaN  NaN  NaN  NaN  NaN
#            0.0500  NaN  NaN  NaN  NaN  NaN
#            0.1000  NaN  NaN  NaN  NaN  NaN
# adaptive   0.0001  NaN  NaN  NaN  NaN  NaN
#            0.0010  NaN  NaN  NaN  NaN  NaN
#            0.0050  NaN  NaN  NaN  NaN  NaN
#            0.0100  NaN  NaN  NaN  NaN  NaN
#            0.0500  NaN  NaN  NaN  NaN  NaN
#            0.1000  NaN  NaN  NaN  NaN  NaN

# %%
# for LR_o in LR_options:
#     for LRI_o in LRI_options:
#         for rep in tune_df.columns:
#             house_mlp = MLPRegressor(hidden_layer_sizes=(13,), max_iter=2000,
#                                    activation='relu',solver='lbfgs',
#                                    learning_rate=LR_o, learning_rate_init= LRI_o)

#             house_mlp.fit(X_train_s, y_train_s)
#             y_tune_predict = house_mlp.predict(X_tune)
#             RSME = np.sqrt(np.sum((y_tune_predict - y_tune)**2)/n)
            
#             tune_df.at[(LR_o,LRI_o),rep] = RSME
#         print((LR_o,LRI_o))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('constant', 0.0001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('constant', 0.001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('constant', 0.005)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('constant', 0.01)
# ('constant', 0.05)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('constant', 0.1)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.0001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.005)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.01)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.05)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('invscaling', 0.1)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.0001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.001)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.005)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.01)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.05)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('adaptive', 0.1)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
# tune_df['Mean'] = tune_df[
#     ['R{}'.format(i) for i in range(num_repetition)]].mean(axis=1)
# tune_df['Min'] = tune_df[
#     ['R{}'.format(i) for i in range(num_repetition)]].min(axis=1)
# tune_df.sort_values('Mean')
# Out:
#                               R0             R1             R2             R3  \
# LR         rate
# constant   0.0010  171077.278639  146930.019803  143348.190447  136764.539736
# invscaling 0.0001  163809.367078  144249.573426  133891.671147  144346.246242
# constant   0.0001  176038.684873  140957.379587  144260.482146  138777.716887
# adaptive   0.0001    164350.9947  167460.743351  148532.817554  126679.405312
# invscaling 0.0500  137395.400816  133692.843821  165431.100144  173320.063801
# adaptive   0.1000  161829.691369  170113.578709  175877.890529  141947.340059
#            0.0050  167812.594802   145262.29644   162578.36566   163465.94913
# constant   0.0050  174612.607978  165260.676622  164957.092783  142978.812543
# adaptive   0.0500  163596.024111   169443.11709  142772.215036  179357.598913
#            0.0010  164280.157143  167624.574503  174450.173741  164225.219044
#            0.0100  164505.888528  176756.333673  127140.854596  173849.835672
# invscaling 0.0100  165540.390658  141098.049255   171212.75794  168467.177749
#            0.1000   145535.14566  169580.763194  166191.693024  159156.580169
#            0.0010  165721.960039  220948.365979  136719.330962  135612.910571
# constant   0.0500  169370.264053  168598.983566  175214.649754  175216.983089
# invscaling 0.0050  169180.344599  141328.054133  169284.557004  182854.779854
# constant   0.0100   155189.64592  163400.572235  184666.388493  174236.619601
#            0.1000   168561.43073  170030.500344  187513.786328  170274.529263
#
#                               R4           Mean            Min
# LR         rate
# constant   0.0010  148793.231307  149382.651986  136764.539736
# invscaling 0.0001  175263.875736  152312.146726  133891.671147
# constant   0.0001   164648.03598  152936.459895  138777.716887
# adaptive   0.0001  166428.098932  154690.411970  126679.405312
# invscaling 0.0500  164030.611301  154774.003977  133692.843821
# adaptive   0.1000  134397.187405  156833.137614  134397.187405
#            0.0050  148796.882862  157583.217779  145262.296440
# constant   0.0050  142413.800894  158044.598164  142413.800894
# adaptive   0.0500  144859.017173  160005.594465  142772.215036
#            0.0010  140486.876891  162213.400264  140486.876891
#            0.0100  169502.069682  162350.996430  127140.854596
# invscaling 0.0100  166288.948093  162521.464739  141098.049255
#            0.1000  174228.717232  162938.579856  145535.145660
#            0.0010    166671.4844  165134.810390  135612.910571
# constant   0.0500  140320.500822  165744.276257  140320.500822
# invscaling 0.0050  168984.515948  166326.450307  141328.054133
# constant   0.0100  174244.734106  170347.592071  155189.645920
#            0.1000  165294.057237  172334.860780  165294.057237

# %%
# tune_df.sort_values('Min')
# Out:
#                               R0             R1             R2             R3  \
# LR         rate
# adaptive   0.0001    164350.9947  167460.743351  148532.817554  126679.405312
#            0.0100  164505.888528  176756.333673  127140.854596  173849.835672
# invscaling 0.0500  137395.400816  133692.843821  165431.100144  173320.063801
#            0.0001  163809.367078  144249.573426  133891.671147  144346.246242
# adaptive   0.1000  161829.691369  170113.578709  175877.890529  141947.340059
# invscaling 0.0010  165721.960039  220948.365979  136719.330962  135612.910571
# constant   0.0010  171077.278639  146930.019803  143348.190447  136764.539736
#            0.0001  176038.684873  140957.379587  144260.482146  138777.716887
#            0.0500  169370.264053  168598.983566  175214.649754  175216.983089
# adaptive   0.0010  164280.157143  167624.574503  174450.173741  164225.219044
# invscaling 0.0100  165540.390658  141098.049255   171212.75794  168467.177749
#            0.0050  169180.344599  141328.054133  169284.557004  182854.779854
# constant   0.0050  174612.607978  165260.676622  164957.092783  142978.812543
# adaptive   0.0500  163596.024111   169443.11709  142772.215036  179357.598913
#            0.0050  167812.594802   145262.29644   162578.36566   163465.94913
# invscaling 0.1000   145535.14566  169580.763194  166191.693024  159156.580169
# constant   0.0100   155189.64592  163400.572235  184666.388493  174236.619601
#            0.1000   168561.43073  170030.500344  187513.786328  170274.529263
#
#                               R4           Mean            Min
# LR         rate
# adaptive   0.0001  166428.098932  154690.411970  126679.405312
#            0.0100  169502.069682  162350.996430  127140.854596
# invscaling 0.0500  164030.611301  154774.003977  133692.843821
#            0.0001  175263.875736  152312.146726  133891.671147
# adaptive   0.1000  134397.187405  156833.137614  134397.187405
# invscaling 0.0010    166671.4844  165134.810390  135612.910571
# constant   0.0010  148793.231307  149382.651986  136764.539736
#            0.0001   164648.03598  152936.459895  138777.716887
#            0.0500  140320.500822  165744.276257  140320.500822
# adaptive   0.0010  140486.876891  162213.400264  140486.876891
# invscaling 0.0100  166288.948093  162521.464739  141098.049255
#            0.0050  168984.515948  166326.450307  141328.054133
# constant   0.0050  142413.800894  158044.598164  142413.800894
# adaptive   0.0500  144859.017173  160005.594465  142772.215036
#            0.0050  148796.882862  157583.217779  145262.296440
# invscaling 0.1000  174228.717232  162938.579856  145535.145660
# constant   0.0100  174244.734106  170347.592071  155189.645920
#            0.1000  165294.057237  172334.860780  165294.057237

# %% [markdown]
# #Tune for max_iter, shuffle

# %%
num_repetition = 5
max_iterations_options = [500,1000,2000,5000,10000]
shuffle_options = [True,False]

my_index = pd.MultiIndex.from_product([max_iterations_options,shuffle_options],
                                     names=('Max Iterations', 'shuffle'))

tune_df = pd.DataFrame(index = my_index,
                       columns=['R{}'.format(i) for i in range(num_repetition)])

tune_df
# Out:
#                          R0   R1   R2   R3   R4
# Max Iterations shuffle
# 500            True     NaN  NaN  NaN  NaN  NaN
#                False    NaN  NaN  NaN  NaN  NaN
# 1000           True     NaN  NaN  NaN  NaN  NaN
#                False    NaN  NaN  NaN  NaN  NaN
# 2000           True     NaN  NaN  NaN  NaN  NaN
#                False    NaN  NaN  NaN  NaN  NaN
# 5000           True     NaN  NaN  NaN  NaN  NaN
#                False    NaN  NaN  NaN  NaN  NaN
# 10000          True     NaN  NaN  NaN  NaN  NaN
#                False    NaN  NaN  NaN  NaN  NaN

# %%
# n = len(y_tune)
# for max_iterations_o in max_iterations_options:
#     for shuffle_o in shuffle_options:
#         for rep in tune_df.columns:
#             house_mlp = MLPRegressor(hidden_layer_sizes=(10,8), max_iter=max_iterations_o,
#                                    activation='relu',solver='lbfgs',
#                                    learning_rate='constant', learning_rate_init= 0.0010,
#                                    shuffle = shuffle_o)

#             house_mlp.fit(X_train_s, y_train_s)
#             y_tune_predict = house_mlp.predict(X_tune)
#             RSME = np.sqrt(np.sum((y_tune_predict - y_tune)**2)/n)
            
#             tune_df.at[(max_iterations_o,shuffle_o),rep] = RSME
#         print((max_iterations_o,shuffle_o))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (500, True)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (500, False)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (1000, True)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (1000, False)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (2000, True)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# (2000, False)
# (5000, True)
# (5000, False)
# (10000, True)
# (10000, False)

# %%
# tune_df['Mean'] = tune_df[
#     ['R{}'.format(i) for i in range(num_repetition)]].mean(axis=1)
# tune_df['Min'] = tune_df[
#     ['R{}'.format(i) for i in range(num_repetition)]].min(axis=1)
# tune_df.sort_values('Min')
# Out:
#                                    R0             R1             R2  \
# Max Iterations shuffle
# 1000           False    163327.937761  123551.521583  172132.252894
#                True     168906.600523   166603.37824  140240.786155
# 2000           False    128687.229125  162441.498076  161513.319106
# 10000          False    163613.906128   129215.02076  154769.144282
# 2000           True     161588.611183  162468.339819  164712.689356
# 10000          True     165067.366581  152001.447552  162294.894175
# 500            False    166117.873073  164774.641245  142132.430193
#                True     162065.433064  161786.053769  160296.301241
# 5000           False    167047.624864  163722.465421  162411.181809
#                True     164992.897535  164311.640137  162887.818429
#
#                                    R3             R4           Mean  \
# Max Iterations shuffle
# 1000           False    137756.901518  166918.475156  152737.417782
#                True     124531.684986  165195.839334  153095.657847
# 2000           False    169130.472023   168549.06475  158064.316616
# 10000          False    165817.180195  159004.845541  154484.019381
# 2000           True     164050.950893  140244.049431  158612.928136
# 10000          True     167371.140919   140313.03923  157409.577691
# 500            False    165710.568337  141864.029381  156119.908446
#                True     163206.215394  142669.311624  158004.663018
# 5000           False    160238.771426  163574.920536  163398.992811
#                True      198882.81577  169535.315357  172122.097446
#
#                                   Min
# Max Iterations shuffle
# 1000           False    123551.521583
#                True     124531.684986
# 2000           False    128687.229125
# 10000          False    129215.020760
# 2000           True     140244.049431
# 10000          True     140313.039230
# 500            False    141864.029381
#                True     142669.311624
# 5000           False    160238.771426
#                True     162887.818429

# %%
# tune_df.sort_values('Mean')
# Out:
#                                    R0             R1             R2  \
# Max Iterations shuffle
# 1000           False    163327.937761  123551.521583  172132.252894
#                True     168906.600523   166603.37824  140240.786155
# 10000          False    163613.906128   129215.02076  154769.144282
# 500            False    166117.873073  164774.641245  142132.430193
# 10000          True     165067.366581  152001.447552  162294.894175
# 500            True     162065.433064  161786.053769  160296.301241
# 2000           False    128687.229125  162441.498076  161513.319106
#                True     161588.611183  162468.339819  164712.689356
# 5000           False    167047.624864  163722.465421  162411.181809
#                True     164992.897535  164311.640137  162887.818429
#
#                                    R3             R4           Mean  \
# Max Iterations shuffle
# 1000           False    137756.901518  166918.475156  152737.417782
#                True     124531.684986  165195.839334  153095.657847
# 10000          False    165817.180195  159004.845541  154484.019381
# 500            False    165710.568337  141864.029381  156119.908446
# 10000          True     167371.140919   140313.03923  157409.577691
# 500            True     163206.215394  142669.311624  158004.663018
# 2000           False    169130.472023   168549.06475  158064.316616
#                True     164050.950893  140244.049431  158612.928136
# 5000           False    160238.771426  163574.920536  163398.992811
#                True      198882.81577  169535.315357  172122.097446
#
#                                   Min
# Max Iterations shuffle
# 1000           False    123551.521583
#                True     124531.684986
# 10000          False    129215.020760
# 500            False    141864.029381
# 10000          True     140313.039230
# 500            True     142669.311624
# 2000           False    128687.229125
#                True     140244.049431
# 5000           False    160238.771426
#                True     162887.818429

# %% [markdown]
# #Tune for alpha

# %%
alpha_options =[0.00001,0.00005,0.0001,0.0005,0.001,0.005]

tune_df = pd.DataFrame(index = alpha_options,
                       columns=['R{}'.format(i) for i in range(num_repetition)])

tune_df
# Out:
#           R0   R1   R2   R3   R4
# 0.00001  NaN  NaN  NaN  NaN  NaN
# 0.00005  NaN  NaN  NaN  NaN  NaN
# 0.00010  NaN  NaN  NaN  NaN  NaN
# 0.00050  NaN  NaN  NaN  NaN  NaN
# 0.00100  NaN  NaN  NaN  NaN  NaN
# 0.00500  NaN  NaN  NaN  NaN  NaN

# %%
n = len(y_tune)
for alpha_o in alpha_options:
    for rep in tune_df.columns:
        house_mlp = MLPRegressor(hidden_layer_sizes=(13,), max_iter=1000,
                               activation='relu',solver='lbfgs', learning_rate='constant',
                               learning_rate_init= 0.0010, shuffle = False, alpha=alpha_o)
        house_mlp.fit(X_train_s, y_train_s)
        y_tune_predict = house_mlp.predict(X_tune)
        RSME = np.sqrt(np.sum((y_tune_predict - y_tune)**2)/n)
        tune_df.at[alpha_o,rep] = RSME
    print(alpha_o)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 1e-05
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 5e-05
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.0001
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.0005
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.001
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.005
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
tune_df['Mean'] = tune_df[
    ['R{}'.format(i) for i in range(num_repetition)]].mean(axis=1)
tune_df['Min'] = tune_df[
    ['R{}'.format(i) for i in range(num_repetition)]].min(axis=1)
tune_df.sort_values('Min')
# Out:
#                     R0             R1             R2             R3  \
# 0.00010  165611.214436  133399.143125  164746.280646  164543.410422
# 0.00005  168734.720074   137880.71823  141012.394768  162700.502207
# 0.00050  138109.756014  168035.299377  161809.671888  163744.362184
# 0.00500  141179.845128  138111.887062  162775.309263  139623.928094
# 0.00001  166590.665973  142421.064275  140310.960798  165200.118549
# 0.00100  167422.120773  164859.324275  160386.258864  166897.408875
#
#                     R4           Mean            Min
# 0.00010  165438.133181  158747.636362  133399.143125
# 0.00005  169427.336889  155951.134434  137880.718230
# 0.00050  152831.826972  156906.183287  138109.756014
# 0.00500  167154.838863  149769.161682  138111.887062
# 0.00001  162382.211686  155381.004256  140310.960798
# 0.00100  162476.602457  164408.343049  160386.258864

# %%
tune_df.sort_values('Mean')
# Out:
#                     R0             R1             R2             R3  \
# 0.00500  141179.845128  138111.887062  162775.309263  139623.928094
# 0.00001  166590.665973  142421.064275  140310.960798  165200.118549
# 0.00005  168734.720074   137880.71823  141012.394768  162700.502207
# 0.00050  138109.756014  168035.299377  161809.671888  163744.362184
# 0.00010  165611.214436  133399.143125  164746.280646  164543.410422
# 0.00100  167422.120773  164859.324275  160386.258864  166897.408875
#
#                     R4           Mean            Min
# 0.00500  167154.838863  149769.161682  138111.887062
# 0.00001  162382.211686  155381.004256  140310.960798
# 0.00005  169427.336889  155951.134434  137880.718230
# 0.00050  152831.826972  156906.183287  138109.756014
# 0.00010  165438.133181  158747.636362  133399.143125
# 0.00100  162476.602457  164408.343049  160386.258864

# %% [markdown]
# #Tune for Randomness

# %%
random_options = range(1,10)

tune_df = pd.DataFrame(index = random_options,
                       columns=['RSME'])
tune_df
# Out:
#   RSME
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# 5  NaN
# 6  NaN
# 7  NaN
# 8  NaN
# 9  NaN

# %%
n = len(y_tune)
for random_o in random_options:
    house_mlp = MLPRegressor(hidden_layer_sizes=(13,), max_iter=1000,
                               activation='relu',solver='lbfgs', learning_rate='constant',
                               learning_rate_init= 0.0010, shuffle = False, alpha=0.00500, random_state=random_o)
    house_mlp.fit(X_train_s, y_train_s)
    y_tune_predict = house_mlp.predict(X_tune)
    RSME = np.sqrt(np.sum((y_tune_predict - y_tune)**2)/n)
    tune_df.at[random_o,'RSME'] = RSME
    print(random_o)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 1
# 2
# 3
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 4
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 5
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 6
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 7
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 8
# 9

# %%
tune_df
# Out:
#             RSME
# 1  176099.268134
# 2  191028.425483
# 3  186085.756395
# 4  159196.243054
# 5  179206.149925
# 6  198484.892788
# 7  185016.314445
# 8  194846.458804
# 9  189217.142587

# %% [markdown]
# # Train the tuned MLP on train set

# %%
# Define the model with one hidden layer of 10 nodes
house_mlp = MLPRegressor(hidden_layer_sizes=(13,),max_iter=1000,
                         activation = 'relu',solver='lbfgs',learning_rate='constant',
                         learning_rate_init = 0.0010,shuffle=False,alpha = 0.00500,random_state =4 )

house_mlp.fit(X_train_s, y_train_s)

y_pred = house_mlp.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE:",mse)
print("RMSE:",np.sqrt(mse))
mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)

mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
print("MAPE:", mape)
# Out:
# MSE: 22280474412.487686
# RMSE: 149266.45441118942
# MAE: 86428.30747215543
# MAPE: 15.961547853749247
